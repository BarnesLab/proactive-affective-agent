# %% [markdown]
# # 02 - Sensing Alignment
#
# Align sensing data with EMA timestamps:
# - Visualize sensing data coverage per user
# - Test lookback window alignment
# - Feature extraction pipeline

# %%
from pathlib import Path
import pandas as pd

DATA_DIR = Path("../data")
