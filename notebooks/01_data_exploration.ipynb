# %% [markdown]
# # 01 - Data Exploration
#
# Explore the BUCS cancer survivorship dataset:
# - EMA data (daily & weekly)
# - Passive sensing data (8 sensors)
# - Baseline trait data
# - Data quality & missingness

# %%
from pathlib import Path
import pandas as pd

DATA_DIR = Path("../data")
