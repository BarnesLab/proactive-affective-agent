# %% [markdown]
# # 03 - Agent Prototype
#
# Prototype the PersonalAgent:
# - V1 structured workflow walkthrough
# - V2 autonomous agent walkthrough
# - Single-user end-to-end test

# %%
from pathlib import Path

PROJECT_ROOT = Path("..").resolve()
