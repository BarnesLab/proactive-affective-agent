# %% [markdown]
# # 04 - Evaluation Analysis
#
# Analyze evaluation results:
# - V1 vs V2 comparison
# - Per-user performance breakdown
# - Learning curves (cold → warm)
# - Receptivity prediction analysis

# %%
from pathlib import Path
import pandas as pd

OUTPUT_DIR = Path("../outputs")
